# %%
def name(var, namespace):
    return [x for x in namespace if namespace[x] is var][0]

# %%
a=4

# %%
name(a,globals())
# Out:
# 'a'

# %%
import pandas as pd
data=pd.read_csv('test.csv')

# %%
name(data,globals())
# Out:
# 'data'

# %%
globals()['a']
# Out:
# 4

# %%
locals()['a']
# Out:
# 4

# %%
locals()['a']
# Out:
# 4

# %%
globals()==locals()
# Out:
# True

# %%
def names(dat_name):
    for x in globals():
        if globals()[x] is dat_name:
               return x

# %%
dat=data.copy()

# %%
b=data

# %%
names(b)
# Out:
# 'data'

# %%
names(dat)
# Out:
# 'dat'

# %%
names(data)
# Out:
# 'data'

# %%
names(data)
# Out:
# 'data'

# %%
globals()['_i112']
# Out:
# "globals()['a']"

# %%
globals()['a']
# Out:
# 4

# %%
globals()['_i118']
# Out:
# "globals()['_i114']"

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def namestr(obj, namespace):\n    return [name for name in namespace if namespace[name] is obj]',
#   'a=4',
#   'namestr(a,global)',
#   'namestr(a,globals())',
#   'def namestr(obj, namespace):\n    return [name for name in namespace if namespace[name] is obj][0]',
#   'a=4',
#   'namestr(a,globals())',
#   "import pandas as pd\ndata=read_csv('test')",
#   "import pandas as pd\ndata=pd.read_csv('test')",
#   "import pandas as pd\ndata=pd.read_csv('test.csv')",
#   'namestr(data,globals())',
#   'def name(var, namespace):\n    return [x for x in namespace if namespace[x] is obj][0]',
#   'a=4',
#   'namestr(a,globals())',
#   'name(a,globals())',
# ...

# %%
names_locals
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14148/2400958320.py in <module>
# ----> 1 names_locals
#
# NameError: name 'names_locals' is not defined

# %%
vars()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'def namestr(obj, namespace):\n    return [name for name in namespace if namespace[name] is obj]',
#   'a=4',
#   'namestr(a,global)',
#   'namestr(a,globals())',
#   'def namestr(obj, namespace):\n    return [name for name in namespace if namespace[name] is obj][0]',
#   'a=4',
#   'namestr(a,globals())',
#   "import pandas as pd\ndata=read_csv('test')",
#   "import pandas as pd\ndata=pd.read_csv('test')",
#   "import pandas as pd\ndata=pd.read_csv('test.csv')",
#   'namestr(data,globals())',
#   'def name(var, namespace):\n    return [x for x in namespace if namespace[x] is obj][0]',
#   'a=4',
#   'namestr(a,globals())',
#   'name(a,globals())',
# ...

# %%
vars()['data'] is data
# Out:
# True
